# %%
# !pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.17.0 does not provide the extra 'srv'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 57.4 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi

# %%
uri = "mongodb+srv://senukirathnayake:Senu%402005@cluster0.xnn6mze.mongodb.net/?appName=Cluster0"

client = MongoClient(uri, server_api=ServerApi('1'))

try:

    client.admin.command('ping')
    print("Successfully connected to MongoDB Atlas")
except Exception as e:
    print(f"Failed to connect to MongoDB: {e}")

# %%
db = client["northstar_activity"]


hub = db["hubs"]
app_event = db["corrected_app_events"]
customer = db["corrected_drivers"]
order = db["corrected_order"]
customer = db["corrected_customers"]
deliverie = db["corrected_deliveries"]
driver = db["corrected_drivers"]
vehicle = db["corrected_vehicles"]
incident = db["corrected_incidents"]

# %%
import pandas as pd

df = pd.read_csv('hubs.csv')

data_dict = df.to_dict('records')

try:
    if data_dict:
        result = hubs.insert_many(data_dict)
        print(f"✅ Successfully imported {len(result.inserted_ids)} hubs!")
    else:
        print("⚠️ The sheet is empty.")
except Exception as e:
    print(f"❌ Error during import: {e}")

# %%
db.deliveries.insert_one({
    "delivery_id": "D1001",
    "status": "Failed",
    "delay_minutes": 35
})

# %%
failed = db.deliveries.find({"status": "Failed"})
for f in failed:
    print(f)

# %%
db.deliveries.aggregate([
    {
        "$group": {
            "_id": "$driver_id",
            "avg_delay": {"$avg": "$delay_minutes"}
        }
    }
])
